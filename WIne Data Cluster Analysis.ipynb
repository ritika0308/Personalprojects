# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
wine_data = pd.read_csv("wine.data", names=["Class", "Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols", "Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity", "Hue","OD280/OD315 of diluted wines","Proline"])
#Reading the .data file and adding the column headers from the .names file

# %%
wine_data
#displaying the wine dataframe
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
wine_data.columns
#displaying all the column headers in the wine dataframe
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
wine_data.isnull().sum()
#to check if any of the columns in the dataframe have null values
#as we see none of the columns have null values
# Out:
# Class                           0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
wine_data.isna().sum()
#to check if any of the columns in the dataframe have NA values
#as we see none of the columns have NA values
# Out:
# Class                           0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
from sklearn.cluster import DBSCAN
from collections import Counter

# %%
wine_dbscan = DBSCAN(eps=25, min_samples = 3).fit(wine_data.iloc[:,1:14])
#performing DBSCAN with min pts = 3 and epsilon = 25

# %%
wine_data2= wine_data
wine_data2['DBSCAN Labels']=wine_dbscan.labels_ #adding the lables as a column in the dataframe
print(Counter(wine_dbscan.labels_)) #counting the number of values in each label
# Out:
# Counter({2: 115, 0: 18, -1: 16, 4: 12, 3: 11, 1: 3, 5: 3})

# %%
wine_data2 #displaying the dataframe
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
wine_data_normalized = normalize(wine_data) #normalizing the wine data before performing Principal Component Analysis
pca_winedata = PCA(3) #reducing the dimensionality to trivariate data
pca_winedata.fit(wine_data_normalized)
  
pca_winedf = pd.DataFrame(pca_winedata.transform(wine_data_normalized)) #adding the reduced data into a dataframe
  
print(pca_winedf.head())
# Out:
#           0         1         2
# 0 -0.037535  0.008759 -0.000767
# 1 -0.061385  0.006380 -0.001566
# 2 -0.069850 -0.000569 -0.001848
# 3 -0.079565  0.001573 -0.001149
# 4  0.005359  0.005323 -0.001125

# %%
print("Total explained variance ratio of trivariate data is: ",pca_winedata.explained_variance_ratio_[0]+pca_winedata.explained_variance_ratio_[1]+pca_winedata.explained_variance_ratio_[2])
# Out:
# Total explained variance ratio of trivariate data is:  0.9946723750936691

# %%
#for generating an array of colors for the 7 clusters(-1,0,1,2,3,4,5) we have which will be used in the 3D Plot
from matplotlib import colors as mcolors
import math
clusters = 7
colors = list(zip(*sorted((
                    tuple(mcolors.rgb_to_hsv(
                          mcolors.to_rgba(color)[:3])), name)
                     for name, color in dict(
                            mcolors.BASE_COLORS, **mcolors.CSS4_COLORS
                                                      ).items())))[1]
skips = math.floor(len(colors[30 : -35])/clusters)
cluster_colors = colors[30 : -35 : skips]

cluster_colors
# Out:
# ('orangered',
#  'antiquewhite',
#  'gold',
#  'yellowgreen',
#  'green',
#  'lightcyan',
#  'deepskyblue')

# %%
#generates a 3D scatter plot where each data point has a color related to its corresponding cluster
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib as mpl

#mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(32,20))
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(pca_winedf[0], pca_winedf[1], pca_winedf[2], 
           c = list(map(lambda label : cluster_colors[label],
                                            wine_dbscan.labels_)))

str_labels = list(map(lambda label:'% s' % label, wine_dbscan.labels_))
   
list(map(lambda data1, data2, data3, str_label:
        ax.text(data1, data2, data3, s = str_label, size = 10,
        zorder = 20, color = 'k'), pca_winedf[0], pca_winedf[1],
        pca_winedf[2], str_labels))

plt.show()
